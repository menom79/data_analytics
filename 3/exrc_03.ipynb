# %% [markdown]
# # Data Analytics Spring 2023 &mdash; Exercises 3
#
# ### A K M Mahmudul Haque
#
# Last modified: Wed Feb 7 at 13:57
#
# - Five problems + round 2 peer review
# - Round 2 peer review deadline: **Tue Feb 13 at noon**
# - Problems deadline: **Tue Feb 20 at noon**
# - The theme should be plotting and statistics (but we'll see)
# - **Make a copy of the original notebook** (right click & duplicate) and add your answers (new cells) there
# - Note: maybe **no autosave** (so keep hitting that ctrl-s / cmd-s button)
# - Please make both your code and your notebook readable
# - When you are done, run the handin code cell at the end of this notebook
# - The original notebook may change after publication, but the
#   changes should be minor
# - Keep your originals up to date by running the code cell below:

# %%
import os
os.system('/usr/bin/bash /home/varpha/data_analytics/bin/config.sh');

# %% [markdown]
# ## Greetings from Harri
#
# Last year I took this round more or less directly from the old course, and the students complained that it was a stupid round. So this time it's a bit different at least!
#
# You don't need to lose your goodnight sleep for problem 5. I just left the AI-generated stuff there... Instead, concentrate on the very first sentence of the problem description (*"Your task is..."*). I'm genuinely interested in the answers, and I don't know them beforehand myself!
#
# There is not much statistics here (maybe not too much plotting either), but don't worry. We will discuss this in our Teams session on Tue Feb 13.

# %% [markdown]
# ## Round 2 peer review
#
# **Deadline: Tue Feb 13 at noon**
#
# In case you handed in your round 02 exercises, your folder `private/exrc_02/peer_review` should contain an anonymous round 02 solutions notebook of another student. In addition, some model solutions for round 02 are in the folder `public/model_solutions`.
#
# Write a few paragraphs of text (plain or markdown) into your favourite text editor and submit by running the code cell below. Please address the following issues:
#
# - Are the solutions okay? Can you understand / run the code?<br/>
# - What do you think about the solutions?
# - How many points out of 5 do they deserve as a whole?
# - How many points would you give to yourself and why?
# - Any feedback or comments to Harri?
#
# Harri will read and grade your reviews as follows:
# - nonexistent or nearly so = 0p
# - something written = 1-2p
# - well written 3p.
#
# When done with writing your review, please run the code cell below. It asks you to copy-paste your review text to a field that will become visible once you run the cell.

# %%
import sys
sys.path.append('/home/varpha/data_analytics/lib')
from handin import submit_peer_review
submit_peer_review()

# %% [markdown]
# You may double check your review submission by running the following in the terminal (copy-paste & press enter):
#
# ```
# cat /home/varpha/data_analytics/private/AB0208/exrc_02/peer_review/review_by_AB0208.txt
# ```

# %% [markdown]
# ## Problem 1. Gitlab (part 1/2)
#
# a) If you haven't done so already, please create a private [LabraNet GitLab](https://gitlab.labranet.jamk.fi) project named `data-analytics-spring-2024` for this course.
#
#   + You can also rename an existing project of yours.
#   + See e.g. [these instructions](https://docs.gitlab.com/ee/user/project/).
#
#   > <span style="font-size:0.8em;"><b>A clarification:</b> There is the public GitLab (gitlab.com) available for anyone, and then we have our own LabraNet instance available for LabraNet users. The public one sometimes has better documentation.</span>
#
#
# b) Please remove `varpha` from your project members, in case it was there in the first place.
#    + (Many added it during our opening weekend.)
#    + Instead, add user `x1234` (@x12341) as a **maintainer** for your project.
#    + (Only maintainers can push to main branch.)
#    + See e.g. [these instructions](https://docs.gitlab.com/ee/user/project/members/#add-users-to-a-project).
#
# Harri will let you know how it went in a Teams thread. Easy one point for all!
#
# **Why** are we doing this:
#    - It's good to have a `git` instance for one's stuff, kind of standard nowadays.
#    - See [this Teams post](https://teams.microsoft.com/l/message/19:Vlddtasi97_uWJ_QI73D8U0PZbYgYZyPf-G1MSpu2V81@thread.tacv2/1707131455956?tenantId=6e9eaaf0-3ff7-4de9-8cd4-1ffbd45951b9&groupId=5865b97a-b517-4122-9704-304b6ab34ce7&parentMessageId=1707129166057&teamName=Data%20Analytics%2C%20Spring%202024&channelName=General&createdTime=1707131455956&allowXTenantAccess=false).
#    - GitLab has an API and can be used e.g. for data analysis tasks (see problem 5).
#
# Our public repository is [here](https://gitlab.labranet.jamk.fi/varpha/dan-spring2024). It currently contains:
#   - The `data_analytics/public` from our hub
#   - Mika's documentation [rendered here](https://varpha.pages.labranet.jamk.fi/dan-spring2024)
#   - a medium.com auto-hack test (see problem 2 below).

# %% [markdown]
# ## Problem 2. Matplotlib & Seaborn
#
# Please spend about 60 to 90 minutes of effective time studying:
#
# - [Mika's material about plotting](https://dan-spring2024-varpha-88169c3779a1710ff05907c99be44ae1d38051dc7.pages.labranet.jamk.fi/Materials/12-Datan_visualisointi_eng/)
# - [This article](https://medium.com/towards-data-science/demystifying-matplotlib-3895ab229a63), also found [here](https://gitlab.labranet.jamk.fi/varpha/dan-spring2024/-/blob/main/medium.com/towards-data-science/demystifying-matplotlib-3895ab229a63.html?ref_type=heads) (download html & open in your browser).
#
# Then apply what you've learned in the next three problems, referring to the articles and your learning process.

# %% [markdown]
# ## Problem 3. Correlation & scatterplot
# [This file](https://student.labranet.jamk.fi/~varpha/data_analytics/exrc03p01_bicycles.txt) has data on available public city bicycles in four stations in Helsinki (summer 2017). Amounts are hourly averages.
#
# [This file](https://student.labranet.jamk.fi/~varpha/data_analytics/exrc03p01_weather.csv) has hourly weather observations from Helsinki from same period.
#
# Load both files as DataFrames and combine the DataFrames so that the corresponding hours are at the same rows.
#
# Any hour that are in either of the files should be included (the bicycle file misses some hours). Remove any overlapping columns.
#
# Finally, give the [correlation coefficient](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.corr.html) between the temperature and the number of available bicycles at the Sammonpuistikko station. Visualize with a scatterplot.

# %% [markdown]
# ## Problem 4. Opening Questionnaire Analysis.
# Analyze our opening questionnaire results in `public/opening_questionnaire`:
#   - read all the json files into a dataframe
#   - produce some descriptive statistics
#   - produce some charts.
#
# See also the `report.py` file in the directory above.
#
# You have total freedom! Try to imagine that:
#   - this data is from an important questionnaire
#   - you need to present the results to your company CEO & executive board
#   - you have chosen to use jupyter & pandas for the job.
#
# Try to keep things simple. No three-dimensional stuff please!
# The most elegant solution wins! 😊

# %% [markdown]
# ## Problem 5. Gitlab (part 2/2)
#
# Your task is to explore what kind of data is freely available for you in the LabraNet GitLab, and then clearly summarize / visualize the results.
#
# **Please note:** Again, this problem is supposed to be hard. Harri doesn't know the answers in advance. Instead, please do your best in trying to help Harri to better understand the GitLab data available for anyone with a user account.
#
# ### a) Initial instructions
#
# Create a personal access token: `User Settings --> Access Tokens --> Add new token`
#
#   + Freely choose the name for the token (e.g. *dan exrc3* or *dan spring 24*, it's for you only).
#   + The same goes for the expiration date (one can always delete old tokens and create new ones if needed).
#
# Choose the `api` scope (the topmost one).
#
# Create the token and save it for yourself.
#
# ### b) Test code
#
# Below is a code snippet that should work for you too. The API documentation is [here](https://python-gitlab.readthedocs.io). See especially the [Getting Started with the API](https://python-gitlab.readthedocs.io/en/stable/api-usage.html) and [API Examples](https://python-gitlab.readthedocs.io/en/stable/api-objects.html) sections.
#
# See also [this Teams message](https://teams.microsoft.com/l/message/19:Vlddtasi97_uWJ_QI73D8U0PZbYgYZyPf-G1MSpu2V81@thread.tacv2/1707234070223?tenantId=6e9eaaf0-3ff7-4de9-8cd4-1ffbd45951b9&groupId=5865b97a-b517-4122-9704-304b6ab34ce7&parentMessageId=1707213051318&teamName=Data%20Analytics%2C%20Spring%202024&channelName=General&createdTime=1707234070223&allowXTenantAccess=false).
#
# ```python
#
# '''
# - install the python-gitlab library
# - can also be done from the terminal without the %
# - needs to be done once only
#
# '''
# %pip install --user python-gitlab
#
# '''
# - initiate a gitlab api instance
# - having the token hard-coded is a bad habit, please don't include in your handin
# - we'll take a look at a better way later
#
# '''
# gl = gitlab.Gitlab(
#     'https://gitlab.labranet.jamk.fi',
#     private_token='COPY_YOUR_PRIVATE_TOKEN_HERE'
# )
#
# # authenticate
# gl.auth()
#
# # get some of the projects available to you
# projects = gl.projects.list()
#
# # (to get all the projects, see documentation)
#
# # print the results
# for project in projects:
#     print(project)
# ```
#
# ### c) Exercise template (AI-generated & modified):
#
# 1. **Setup and Authentication**:
#
# - Use python-gitlab to connect to the GitLab instance.
# - Ensure you have a personal access token for accessing public data.
#
# 2. **Data Collection**:
#
# - Use the python-gitlab API to fetch e.g.:
#
#   - List of public projects and their details.
#   - Public groups and user information.
#
# 3. **Data Preparation**:
#
# - Use pandas to organize the data into DataFrames.
# - Clean and preprocess the data (handle missing values, parse dates, etc.).
#
# 4. **Exploratory Data Analysis (EDA)**:
#
# - Analyze the distribution of projects, contributions, and group memberships.
# - Identify the most popular projects based on stars and forks.
#
# 5. **Visualization**:
#
# - Use matplotlib or seaborn to create visualizations:
#   - Histograms of project counts, star counts, and forks.
#   - Analysis of user activity (commits, issues, etc.).
#
# 6. **Insights and Conclusion**:
#
# - Summarize your findings.
# - Discuss any interesting trends or outliers observed in the data.

# %% [markdown]
# ## Handin your final answers by running the code cell below.
# - Save your latest changes first.
# - Please remove anything that may identify you to your anonymous reviewer.
# - (On the other hand, Harri's anonymization script should work well now.)
# - You may run the code cell as many times as you wish.
# - Your permission to write the handin file ends at the deadline.
# - See also: [This thread](https://teams.microsoft.com/l/message/19:Vlddtasi97_uWJ_QI73D8U0PZbYgYZyPf-G1MSpu2V81@thread.tacv2/1707027449839?tenantId=6e9eaaf0-3ff7-4de9-8cd4-1ffbd45951b9&groupId=5865b97a-b517-4122-9704-304b6ab34ce7&parentMessageId=1707027449839&teamName=Data%20Analytics%2C%20Spring%202024&channelName=General&createdTime=1707027449839&allowXTenantAccess=false).

# %%
import sys
sys.path.append('/home/varpha/data_analytics/lib')
from handin import handin_exrc_03
handin_exrc_03()
