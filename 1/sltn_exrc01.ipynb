# %%
# Import NumPy library
import numpy as np

'''Explanation: In the first cell, we import the NumPy library, which is necessary for using the numpy.random.choice function.'''

# Example 1: Sampling without replacement
data = np.array([1, 2, 3, 4, 5])
sample = np.random.choice(data, size=3, replace=False)

print("Example 1:")
print("Original array:", data)
print("Sampled without replacement:", sample)

'''Explanation: In the second cell, we demonstrate how to use numpy.random.choice to sample three elements without replacement from an array [1, 2, 3, 4, 5].'''

# Example 2: Sampling with replacement
sample_with_replacement = np.random.choice(data, size=5, replace=True)

print("\nExample 2:")
print("Sampled with replacement:", sample_with_replacement)

'''Explanation: In the third cell, we show how to sample five elements with replacement from the same array, allowing duplicates in the output.'''

# Example 3: Weighted sampling
weighted_data = np.array([1, 2, 3, 4, 5])
weights = np.array([0.1, 0.2, 0.3, 0.2, 0.2])
weighted_sample = np.random.choice(weighted_data, size=3, replace=False, p=weights)

print("\nExample 3:")
print("Weighted data array:", weighted_data)
print("Weights:", weights)
print("Weighted sample:", weighted_sample)

'''Explanation: In the fourth cell, we illustrate how to perform weighted sampling using the p parameter, where each element has specified probabilities. The example includes an array [1, 2, 3, 4, 5] with corresponding weights.'''
# Out:
# Example 1:
# Original array: [1 2 3 4 5]
# Sampled without replacement: [3 1 2]
#
# Example 2:
# Sampled with replacement: [1 4 5 2 4]
#
# Example 3:
# Weighted data array: [1 2 3 4 5]
# Weights: [0.1 0.2 0.3 0.2 0.2]
# Weighted sample: [2 4 5]
# 'Explanation: In the fourth cell, we illustrate how to perform weighted sampling using the p parameter, where each element has specified probabilities. The example includes an array [1, 2, 3, 4, 5] with corresponding weights.'

# %%
import csv
from datetime import datetime
from itertools import groupby

# Update the CSV location
csv_location = './data/prob2_AB0208.csv'

with open(csv_location) as handle:
    mydata = list(csv.DictReader(handle))

# Display the column names to identify the correct ones
print("Column names in the CSV file:", mydata[0].keys())

# Update the column names in the code accordingly
# For example, if the actual column names are 'TimeStamp', 'RotorSpeed_rpm', 'WindSpeed_mps'
mydata = [{'Timestamp': datetime.strptime(row['TimeStamp'], '%Y-%m-%d %H:%M:%S.%f').strftime('%m/%d/%Y %H:%M:%S'),
           'Rotorspeed': float(row['RotorSpeed_rpm']) if row['RotorSpeed_rpm'] else 0.0,
           'Windspeed': float(row['WindSpeed_mps']) if row['WindSpeed_mps'] else 0.0}
          for row in mydata]

# a) Convert timestamps into the format MM/dd/yyyy HH:mm:ss using map
mydata = list(map(lambda row: {'Timestamp': datetime.strptime(row['Timestamp'], '%m/%d/%Y %H:%M:%S').strftime('%m/%d/%Y %H:%M:%S'),
                               'Rotorspeed': row['Rotorspeed'],
                               'Windspeed': row['Windspeed']},
                 mydata))

# b) Sort the rows according to increasing rotorspeed using sorted and lambda
mydata = sorted(mydata, key=lambda x: x['Rotorspeed'])

# c) Add a column called WindSpeed_Group using itertools.groupby
def categorize_windspeed(windspeed):
    if windspeed < 5:
        return 'A'
    elif 5 <= windspeed <= 10:
        return 'B'
    else:
        return 'C'

# Add WindSpeed_Group column
for row in mydata:
    row['WindSpeed_Group'] = categorize_windspeed(row['Windspeed'])

# Display the modified data
for row in mydata:
    print(row)
# Out:
# Column names in the CSV file: dict_keys(['TimeStamp', 'ReactivePower_kVAr', 'Power_kW', 'WindSpeed_mps', 'ErrorCode', 'GenState', 'RunState', 'RotorSpeed_rpm', 'RotorSpeedAve', 'RotorOverSpeed', 'RotorUnderSpeed'])
# {'Timestamp': '04/23/2018 08:56:03', 'Rotorspeed': -0.3300243, 'Windspeed': 15.1633, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 12:38:45', 'Rotorspeed': -0.2700199, 'Windspeed': 9.455032, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 07:14:16', 'Rotorspeed': -0.2550188, 'Windspeed': 13.22011, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 07:31:58', 'Rotorspeed': -0.2400177, 'Windspeed': 9.337159, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 12:07:51', 'Rotorspeed': -0.2400177, 'Windspeed': 7.309283, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 13:39:19', 'Rotorspeed': -0.2400177, 'Windspeed': 6.916753, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 14:44:13', 'Rotorspeed': -0.2250166, 'Windspeed': 6.644386, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 10:41:32', 'Rotorspeed': -0.2250166, 'Windspeed': 7.05637, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 06:28:30', 'Rotorspeed': -0.2250166, 'Windspeed': 11.39365, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 07:14:13', 'Rotorspeed': -0.2250166, 'Windspeed': 12.60671, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/05/2018 11:58:10', 'Rotorspeed': -0.2100155, 'Windspeed': 9.464188, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 00:03:01', 'Rotorspeed': -0.2100155, 'Windspeed': 6.785148, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 22:09:55', 'Rotorspeed': -0.2100155, 'Windspeed': 11.87544, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 10:49:14', 'Rotorspeed': -0.2100155, 'Windspeed': 11.56187, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/20/2018 14:24:57', 'Rotorspeed': -0.1950144, 'Windspeed': 13.08393, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 08:30:16', 'Rotorspeed': -0.1950144, 'Windspeed': 14.53045, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 20:26:33', 'Rotorspeed': -0.1950144, 'Windspeed': 10.77567, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 06:43:19', 'Rotorspeed': -0.1950144, 'Windspeed': 8.396462, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 10:57:02', 'Rotorspeed': -0.1950144, 'Windspeed': 9.370347, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/26/2018 10:52:21', 'Rotorspeed': -0.1950144, 'Windspeed': 15.34068, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 15:31:09', 'Rotorspeed': -0.1950144, 'Windspeed': 9.796063, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/19/2018 13:54:23', 'Rotorspeed': -0.1800133, 'Windspeed': 10.55938, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/20/2018 14:24:59', 'Rotorspeed': -0.1800133, 'Windspeed': 11.59048, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/22/2018 16:18:01', 'Rotorspeed': -0.1800133, 'Windspeed': 10.93932, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 11:27:45', 'Rotorspeed': -0.1800133, 'Windspeed': 10.59714, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 20:33:38', 'Rotorspeed': -0.1800133, 'Windspeed': 11.19223, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/25/2018 14:38:35', 'Rotorspeed': -0.1800133, 'Windspeed': 13.02327, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/25/2018 16:12:58', 'Rotorspeed': -0.1800133, 'Windspeed': 10.88782, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/21/2018 03:17:02', 'Rotorspeed': -0.1650122, 'Windspeed': 5.356936, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 03:17:13', 'Rotorspeed': -0.1650122, 'Windspeed': 5.746032, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 03:17:29', 'Rotorspeed': -0.1650122, 'Windspeed': 6.804602, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 05:37:05', 'Rotorspeed': -0.1650122, 'Windspeed': 10.26985, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 22:09:51', 'Rotorspeed': -0.1650122, 'Windspeed': 11.77244, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 01:20:08', 'Rotorspeed': -0.1650122, 'Windspeed': 8.302622, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 07:31:55', 'Rotorspeed': -0.1650122, 'Windspeed': 7.955869, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 10:25:46', 'Rotorspeed': -0.1650122, 'Windspeed': 9.749144, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 11:03:03', 'Rotorspeed': -0.1650122, 'Windspeed': 12.4053, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/25/2018 11:16:51', 'Rotorspeed': -0.1650122, 'Windspeed': 13.67444, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/25/2018 16:28:04', 'Rotorspeed': -0.1650122, 'Windspeed': 4.43455, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/26/2018 10:32:14', 'Rotorspeed': -0.1650122, 'Windspeed': 11.23457, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 13:53:03', 'Rotorspeed': -0.1650122, 'Windspeed': 6.354853, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/26/2018 17:39:14', 'Rotorspeed': -0.1650122, 'Windspeed': 13.35972, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/04/2018 10:56:21', 'Rotorspeed': -0.1500111, 'Windspeed': 10.93932, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/04/2018 12:11:55', 'Rotorspeed': -0.1500111, 'Windspeed': 8.667686, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/05/2018 09:25:35', 'Rotorspeed': -0.1500111, 'Windspeed': 6.579155, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/05/2018 12:12:43', 'Rotorspeed': -0.1500111, 'Windspeed': 6.742805, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/10/2018 10:55:35', 'Rotorspeed': -0.1500111, 'Windspeed': 10.57883, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/10/2018 11:52:40', 'Rotorspeed': -0.1500111, 'Windspeed': 12.73717, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/20/2018 08:37:28', 'Rotorspeed': -0.1500111, 'Windspeed': 6.54139, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:19:52', 'Rotorspeed': -0.1500111, 'Windspeed': 8.972095, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:20:12', 'Rotorspeed': -0.1500111, 'Windspeed': 6.064176, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 03:16:49', 'Rotorspeed': -0.1500111, 'Windspeed': 5.488542, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 03:17:37', 'Rotorspeed': -0.1500111, 'Windspeed': 6.588311, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 00:03:07', 'Rotorspeed': -0.1500111, 'Windspeed': 11.4028, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 10:19:12', 'Rotorspeed': -0.1500111, 'Windspeed': 13.05532, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 20:25:21', 'Rotorspeed': -0.1500111, 'Windspeed': 8.470849, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 20:36:53', 'Rotorspeed': -0.1500111, 'Windspeed': 7.192554, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 08:26:02', 'Rotorspeed': -0.1500111, 'Windspeed': 11.34215, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 08:32:49', 'Rotorspeed': -0.1500111, 'Windspeed': 10.94847, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 13:32:15', 'Rotorspeed': -0.1500111, 'Windspeed': 6.148861, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 10:24:27', 'Rotorspeed': -0.1500111, 'Windspeed': 6.841223, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 10:45:07', 'Rotorspeed': -0.1500111, 'Windspeed': 6.603188, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/26/2018 14:07:01', 'Rotorspeed': -0.1500111, 'Windspeed': 10.40488, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 15:44:36', 'Rotorspeed': -0.1500111, 'Windspeed': 6.981984, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/26/2018 15:57:39', 'Rotorspeed': -0.1500111, 'Windspeed': 12.52202, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/27/2018 18:39:38', 'Rotorspeed': -0.1500111, 'Windspeed': 5.117757, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 13:05:06', 'Rotorspeed': -0.1500111, 'Windspeed': 5.942869, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 13:20:18', 'Rotorspeed': -0.1500111, 'Windspeed': 5.858183, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 13:30:57', 'Rotorspeed': -0.1500111, 'Windspeed': 6.021833, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 12:05:51', 'Rotorspeed': -0.1350099, 'Windspeed': 11.3513, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/04/2018 13:52:17', 'Rotorspeed': -0.1350099, 'Windspeed': 12.59641, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/05/2018 10:52:31', 'Rotorspeed': -0.1350099, 'Windspeed': 4.551279, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/10/2018 15:06:24', 'Rotorspeed': -0.1350099, 'Windspeed': 12.16154, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/17/2018 11:09:54', 'Rotorspeed': -0.1350099, 'Windspeed': 13.56114, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/17/2018 13:11:00', 'Rotorspeed': -0.1350099, 'Windspeed': 14.77878, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/20/2018 08:15:15', 'Rotorspeed': -0.1350099, 'Windspeed': 9.229586, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 10:01:39', 'Rotorspeed': -0.1350099, 'Windspeed': 10.78483, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/20/2018 11:57:49', 'Rotorspeed': -0.1350099, 'Windspeed': 10.68641, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/20/2018 13:14:23', 'Rotorspeed': -0.1350099, 'Windspeed': 12.02536, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/20/2018 13:19:15', 'Rotorspeed': -0.1350099, 'Windspeed': 13.90789, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/20/2018 16:07:00', 'Rotorspeed': -0.1350099, 'Windspeed': 11.18308, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/21/2018 02:27:38', 'Rotorspeed': -0.1350099, 'Windspeed': 8.940053, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:37:58', 'Rotorspeed': -0.1350099, 'Windspeed': 9.164355, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:54:26', 'Rotorspeed': -0.1350099, 'Windspeed': 7.852873, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 03:16:39', 'Rotorspeed': -0.1350099, 'Windspeed': 7.32416, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 03:19:35', 'Rotorspeed': -0.1350099, 'Windspeed': 5.956602, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/22/2018 22:40:51', 'Rotorspeed': -0.1350099, 'Windspeed': 8.443383, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 05:50:43', 'Rotorspeed': -0.1350099, 'Windspeed': 12.37211, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 20:03:33', 'Rotorspeed': -0.1350099, 'Windspeed': 18.80707, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 20:08:10', 'Rotorspeed': -0.1350099, 'Windspeed': 13.20523, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 20:26:40', 'Rotorspeed': -0.1350099, 'Windspeed': 17.27014, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 09:10:58', 'Rotorspeed': -0.1350099, 'Windspeed': 13.41122, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 10:07:10', 'Rotorspeed': -0.1350099, 'Windspeed': 9.777754, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 10:10:19', 'Rotorspeed': -0.1350099, 'Windspeed': 8.920598, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 10:21:20', 'Rotorspeed': -0.1350099, 'Windspeed': 10.93474, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 16:34:39', 'Rotorspeed': -0.1350099, 'Windspeed': 9.187243, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 16:34:40', 'Rotorspeed': -0.1350099, 'Windspeed': 8.114941, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 16:57:52', 'Rotorspeed': -0.1350099, 'Windspeed': 8.743216, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 16:11:36', 'Rotorspeed': -0.1350099, 'Windspeed': 11.11212, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/25/2018 16:34:23', 'Rotorspeed': -0.1350099, 'Windspeed': 6.012678, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/26/2018 10:53:58', 'Rotorspeed': -0.1350099, 'Windspeed': 17.89842, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 10:55:43', 'Rotorspeed': -0.1350099, 'Windspeed': 13.5291, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 14:31:00', 'Rotorspeed': -0.1350099, 'Windspeed': 15.52379, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 16:38:31', 'Rotorspeed': -0.1350099, 'Windspeed': 6.279323, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/27/2018 18:40:22', 'Rotorspeed': -0.1350099, 'Windspeed': 6.298778, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/29/2018 17:30:21', 'Rotorspeed': -0.1350099, 'Windspeed': 6.115674, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/29/2018 18:10:54', 'Rotorspeed': -0.1350099, 'Windspeed': 4.130139, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/29/2018 18:11:40', 'Rotorspeed': -0.1350099, 'Windspeed': 5.520586, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 13:16:40', 'Rotorspeed': -0.1350099, 'Windspeed': 5.038793, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 13:30:53', 'Rotorspeed': -0.1350099, 'Windspeed': 1.774964, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/30/2018 13:36:37', 'Rotorspeed': -0.1350099, 'Windspeed': 5.97949, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/01/2018 03:53:28', 'Rotorspeed': -0.1200088, 'Windspeed': 6.064176, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/03/2018 04:46:03', 'Rotorspeed': -0.1200088, 'Windspeed': 10.45181, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/04/2018 11:21:02', 'Rotorspeed': -0.1200088, 'Windspeed': 11.60422, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/04/2018 13:29:04', 'Rotorspeed': -0.1200088, 'Windspeed': 5.895949, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 13:52:59', 'Rotorspeed': -0.1200088, 'Windspeed': 11.34673, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/05/2018 11:55:59', 'Rotorspeed': -0.1200088, 'Windspeed': 4.17706, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/05/2018 20:16:14', 'Rotorspeed': -0.1200088, 'Windspeed': 2.81408, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/08/2018 09:56:58', 'Rotorspeed': -0.1200088, 'Windspeed': 3.413745, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/08/2018 22:55:47', 'Rotorspeed': -0.1200088, 'Windspeed': 6.05502, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/10/2018 05:33:23', 'Rotorspeed': -0.1200088, 'Windspeed': 12.48884, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/10/2018 09:18:24', 'Rotorspeed': -0.1200088, 'Windspeed': 10.02609, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/17/2018 23:21:48', 'Rotorspeed': -0.1200088, 'Windspeed': 7.904371, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/18/2018 02:25:29', 'Rotorspeed': -0.1200088, 'Windspeed': 5.319171, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/18/2018 13:44:18', 'Rotorspeed': -0.1200088, 'Windspeed': 7.796797, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 12:01:32', 'Rotorspeed': -0.1200088, 'Windspeed': 9.234163, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 15:52:12', 'Rotorspeed': -0.1200088, 'Windspeed': 7.239474, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 15:52:13', 'Rotorspeed': -0.1200088, 'Windspeed': 11.17278, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/21/2018 02:09:45', 'Rotorspeed': -0.1200088, 'Windspeed': 6.330821, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:18:53', 'Rotorspeed': -0.1200088, 'Windspeed': 6.818335, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:22:04', 'Rotorspeed': -0.1200088, 'Windspeed': 9.032749, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:22:08', 'Rotorspeed': -0.1200088, 'Windspeed': 8.99155, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:25:11', 'Rotorspeed': -0.1200088, 'Windspeed': 7.740722, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:26:46', 'Rotorspeed': -0.1200088, 'Windspeed': 8.255701, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 03:24:56', 'Rotorspeed': -0.1200088, 'Windspeed': 4.022566, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/21/2018 03:25:09', 'Rotorspeed': -0.1200088, 'Windspeed': 6.686729, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/22/2018 14:44:07', 'Rotorspeed': -0.1200088, 'Windspeed': 8.569267, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/22/2018 18:01:01', 'Rotorspeed': -0.1200088, 'Windspeed': 11.09381, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 00:30:37', 'Rotorspeed': -0.1200088, 'Windspeed': 13.82893, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 02:24:02', 'Rotorspeed': -0.1200088, 'Windspeed': 10.32592, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 10:32:17', 'Rotorspeed': -0.1200088, 'Windspeed': 8.138972, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 14:05:18', 'Rotorspeed': -0.1200088, 'Windspeed': 8.457116, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 15:33:46', 'Rotorspeed': -0.1200088, 'Windspeed': 7.094135, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 15:33:47', 'Rotorspeed': -0.1200088, 'Windspeed': 7.094135, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 21:01:00', 'Rotorspeed': -0.1200088, 'Windspeed': 6.766837, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 21:04:16', 'Rotorspeed': -0.1200088, 'Windspeed': 8.906865, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 21:29:53', 'Rotorspeed': -0.1200088, 'Windspeed': 8.396462, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 00:46:42', 'Rotorspeed': -0.1200088, 'Windspeed': 11.32269, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 01:51:07', 'Rotorspeed': -0.1200088, 'Windspeed': 7.37108, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 01:54:36', 'Rotorspeed': -0.1200088, 'Windspeed': 13.26245, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 02:13:56', 'Rotorspeed': -0.1200088, 'Windspeed': 9.777754, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 02:35:40', 'Rotorspeed': -0.1200088, 'Windspeed': 12.40072, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 07:06:02', 'Rotorspeed': -0.1200088, 'Windspeed': 6.672997, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 07:32:33', 'Rotorspeed': -0.1200088, 'Windspeed': 8.307199, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 09:48:39', 'Rotorspeed': -0.1200088, 'Windspeed': 15.60389, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 10:08:56', 'Rotorspeed': -0.1200088, 'Windspeed': 10.59714, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 10:22:35', 'Rotorspeed': -0.1200088, 'Windspeed': 6.742805, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 10:45:11', 'Rotorspeed': -0.1200088, 'Windspeed': 7.805952, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 11:01:42', 'Rotorspeed': -0.1200088, 'Windspeed': 6.753104, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 08:04:12', 'Rotorspeed': -0.1200088, 'Windspeed': 3.839462, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/26/2018 13:19:00', 'Rotorspeed': -0.1200088, 'Windspeed': 10.41976, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 16:58:39', 'Rotorspeed': -0.1200088, 'Windspeed': 13.08393, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 18:10:31', 'Rotorspeed': -0.1200088, 'Windspeed': 12.03451, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 18:27:13', 'Rotorspeed': -0.1200088, 'Windspeed': 13.3231, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 18:34:57', 'Rotorspeed': -0.1200088, 'Windspeed': 10.96679, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/27/2018 18:39:07', 'Rotorspeed': -0.1200088, 'Windspeed': 5.829574, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/27/2018 18:41:23', 'Rotorspeed': -0.1200088, 'Windspeed': 5.731155, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/27/2018 18:56:38', 'Rotorspeed': -0.1200088, 'Windspeed': 4.045454, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/29/2018 18:10:35', 'Rotorspeed': -0.1200088, 'Windspeed': 5.356936, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 07:14:12', 'Rotorspeed': -0.1200088, 'Windspeed': 3.624315, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/30/2018 07:14:51', 'Rotorspeed': -0.1200088, 'Windspeed': 1.376713, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/30/2018 13:06:37', 'Rotorspeed': -0.1200088, 'Windspeed': 7.328737, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 13:08:08', 'Rotorspeed': -0.1200088, 'Windspeed': 5.923414, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 13:28:25', 'Rotorspeed': -0.1200088, 'Windspeed': 7.319582, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 13:29:19', 'Rotorspeed': -0.1200088, 'Windspeed': 8.65853, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 13:30:42', 'Rotorspeed': -0.1200088, 'Windspeed': 3.512164, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/30/2018 13:52:49', 'Rotorspeed': -0.1200088, 'Windspeed': 8.228236, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/02/2018 19:26:07', 'Rotorspeed': -0.1050077, 'Windspeed': 13.22926, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/04/2018 04:18:06', 'Rotorspeed': -0.1050077, 'Windspeed': 9.150622, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 05:16:38', 'Rotorspeed': -0.1050077, 'Windspeed': 8.738638, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 09:20:06', 'Rotorspeed': -0.1050077, 'Windspeed': 8.092052, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 09:54:00', 'Rotorspeed': -0.1050077, 'Windspeed': 6.504769, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 10:34:09', 'Rotorspeed': -0.1050077, 'Windspeed': 9.759443, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 14:25:33', 'Rotorspeed': -0.1050077, 'Windspeed': 6.045865, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/05/2018 12:24:34', 'Rotorspeed': -0.1050077, 'Windspeed': 9.646148, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/05/2018 12:26:36', 'Rotorspeed': -0.1050077, 'Windspeed': 6.55169, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/05/2018 13:38:11', 'Rotorspeed': -0.1050077, 'Windspeed': 7.557618, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/05/2018 13:44:24', 'Rotorspeed': -0.1050077, 'Windspeed': 5.632737, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/05/2018 14:13:17', 'Rotorspeed': -0.1050077, 'Windspeed': 6.832068, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/07/2018 00:58:16', 'Rotorspeed': -0.1050077, 'Windspeed': 10.41518, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/08/2018 23:39:47', 'Rotorspeed': -0.1050077, 'Windspeed': 8.026821, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/08/2018 23:41:40', 'Rotorspeed': -0.1050077, 'Windspeed': 6.672997, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/10/2018 11:28:01', 'Rotorspeed': -0.1050077, 'Windspeed': 9.89906, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/10/2018 20:19:36', 'Rotorspeed': -0.1050077, 'Windspeed': 6.850379, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/11/2018 10:09:51', 'Rotorspeed': -0.1050077, 'Windspeed': 9.477921, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/17/2018 11:28:15', 'Rotorspeed': -0.1050077, 'Windspeed': 5.647614, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/17/2018 11:39:16', 'Rotorspeed': -0.1050077, 'Windspeed': 10.98624, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/17/2018 13:26:51', 'Rotorspeed': -0.1050077, 'Windspeed': 12.6811, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/17/2018 13:35:08', 'Rotorspeed': -0.1050077, 'Windspeed': 19.16755, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/17/2018 15:34:19', 'Rotorspeed': -0.1050077, 'Windspeed': 15.91288, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/17/2018 19:45:09', 'Rotorspeed': -0.1050077, 'Windspeed': 14.72728, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/17/2018 23:16:59', 'Rotorspeed': -0.1050077, 'Windspeed': 5.535463, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/18/2018 13:26:48', 'Rotorspeed': -0.1050077, 'Windspeed': 7.145634, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/18/2018 16:04:21', 'Rotorspeed': -0.1050077, 'Windspeed': 8.031399, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 07:06:37', 'Rotorspeed': -0.1050077, 'Windspeed': 7.590805, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 09:30:07', 'Rotorspeed': -0.1050077, 'Windspeed': 5.871916, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 09:35:54', 'Rotorspeed': -0.1050077, 'Windspeed': 8.569267, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 09:54:27', 'Rotorspeed': -0.1050077, 'Windspeed': 4.504358, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/20/2018 10:43:07', 'Rotorspeed': -0.1050077, 'Windspeed': 8.958364, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 12:21:08', 'Rotorspeed': -0.1050077, 'Windspeed': 7.393968, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 12:24:28', 'Rotorspeed': -0.1050077, 'Windspeed': 7.731566, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 12:41:38', 'Rotorspeed': -0.1050077, 'Windspeed': 6.326243, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 16:28:25', 'Rotorspeed': -0.1050077, 'Windspeed': 10.01236, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/21/2018 01:22:55', 'Rotorspeed': -0.1050077, 'Windspeed': 8.944631, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 01:26:14', 'Rotorspeed': -0.1050077, 'Windspeed': 6.8561, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:39:17', 'Rotorspeed': -0.1050077, 'Windspeed': 9.318849, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:55:19', 'Rotorspeed': -0.1050077, 'Windspeed': 9.108279, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 03:04:50', 'Rotorspeed': -0.1050077, 'Windspeed': 8.635642, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 03:23:57', 'Rotorspeed': -0.1050077, 'Windspeed': 6.23698, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 03:24:02', 'Rotorspeed': -0.1050077, 'Windspeed': 3.816574, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/22/2018 06:57:30', 'Rotorspeed': -0.1050077, 'Windspeed': 4.73896, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/22/2018 13:03:23', 'Rotorspeed': -0.1050077, 'Windspeed': 7.722411, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 00:23:37', 'Rotorspeed': -0.1050077, 'Windspeed': 7.225741, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 04:25:02', 'Rotorspeed': -0.1050077, 'Windspeed': 13.83351, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 06:02:27', 'Rotorspeed': -0.1050077, 'Windspeed': 11.7404, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 07:26:29', 'Rotorspeed': -0.1050077, 'Windspeed': 12.32519, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 07:49:33', 'Rotorspeed': -0.1050077, 'Windspeed': 8.195048, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 11:59:35', 'Rotorspeed': -0.1050077, 'Windspeed': 15.04199, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 12:50:03', 'Rotorspeed': -0.1050077, 'Windspeed': 13.09308, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 12:58:05', 'Rotorspeed': -0.1050077, 'Windspeed': 11.7404, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 13:28:55', 'Rotorspeed': -0.1050077, 'Windspeed': 13.80032, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 14:23:24', 'Rotorspeed': -0.1050077, 'Windspeed': 10.10047, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 20:33:44', 'Rotorspeed': -0.1050077, 'Windspeed': 15.2148, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 21:26:13', 'Rotorspeed': -0.1050077, 'Windspeed': 10.38657, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 22:31:44', 'Rotorspeed': -0.1050077, 'Windspeed': 8.864522, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 23:12:06', 'Rotorspeed': -0.1050077, 'Windspeed': 4.869422, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/24/2018 00:17:50', 'Rotorspeed': -0.1050077, 'Windspeed': 5.689957, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 05:33:10', 'Rotorspeed': -0.1050077, 'Windspeed': 10.52734, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 06:32:09', 'Rotorspeed': -0.1050077, 'Windspeed': 7.633148, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 06:44:12', 'Rotorspeed': -0.1050077, 'Windspeed': 9.075092, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 10:30:22', 'Rotorspeed': -0.1050077, 'Windspeed': 11.48749, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 10:33:47', 'Rotorspeed': -0.1050077, 'Windspeed': 8.550957, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 11:00:12', 'Rotorspeed': -0.1050077, 'Windspeed': 10.72417, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 11:01:30', 'Rotorspeed': -0.1050077, 'Windspeed': 8.241969, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 11:15:03', 'Rotorspeed': -0.1050077, 'Windspeed': 8.602455, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 16:54:07', 'Rotorspeed': -0.1050077, 'Windspeed': 4.654275, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/25/2018 10:07:13', 'Rotorspeed': -0.1050077, 'Windspeed': 10.10505, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/25/2018 11:34:30', 'Rotorspeed': -0.1050077, 'Windspeed': 9.749144, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 14:43:08', 'Rotorspeed': -0.1050077, 'Windspeed': 8.958364, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 16:53:52', 'Rotorspeed': -0.1050077, 'Windspeed': 8.320932, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 16:59:34', 'Rotorspeed': -0.1050077, 'Windspeed': 11.96012, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/25/2018 17:54:32', 'Rotorspeed': -0.1050077, 'Windspeed': 7.141056, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/26/2018 10:19:44', 'Rotorspeed': -0.1050077, 'Windspeed': 12.5266, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 14:00:55', 'Rotorspeed': -0.1050077, 'Windspeed': 12.83101, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 14:20:30', 'Rotorspeed': -0.1050077, 'Windspeed': 11.84797, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 14:40:21', 'Rotorspeed': -0.1050077, 'Windspeed': 12.72802, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 14:51:00', 'Rotorspeed': -0.1050077, 'Windspeed': 6.897299, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/26/2018 16:51:57', 'Rotorspeed': -0.1050077, 'Windspeed': 9.838407, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 07:22:53', 'Rotorspeed': -0.1050077, 'Windspeed': 6.293056, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 09:10:29', 'Rotorspeed': -0.1050077, 'Windspeed': 4.420817, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/30/2018 13:25:13', 'Rotorspeed': -0.1050077, 'Windspeed': 6.545968, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/02/2018 08:50:28', 'Rotorspeed': -0.09000664, 'Windspeed': 9.867017, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/02/2018 13:49:44', 'Rotorspeed': -0.09000664, 'Windspeed': 11.60422, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/02/2018 15:20:51', 'Rotorspeed': -0.09000664, 'Windspeed': 11.52411, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/02/2018 19:53:13', 'Rotorspeed': -0.09000664, 'Windspeed': 12.06312, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/02/2018 19:57:00', 'Rotorspeed': -0.09000664, 'Windspeed': 12.71428, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/02/2018 22:19:45', 'Rotorspeed': -0.09000664, 'Windspeed': 4.611932, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/02/2018 23:08:48', 'Rotorspeed': -0.09000664, 'Windspeed': 8.953786, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/03/2018 00:16:48', 'Rotorspeed': -0.09000664, 'Windspeed': 7.356203, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/03/2018 04:45:59', 'Rotorspeed': -0.09000664, 'Windspeed': 10.06843, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/04/2018 03:17:20', 'Rotorspeed': -0.09000664, 'Windspeed': 7.815107, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 07:05:06', 'Rotorspeed': -0.09000664, 'Windspeed': 7.201709, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 08:58:12', 'Rotorspeed': -0.09000664, 'Windspeed': 4.817924, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/04/2018 09:35:26', 'Rotorspeed': -0.09000664, 'Windspeed': 6.860678, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 09:35:27', 'Rotorspeed': -0.09000664, 'Windspeed': 6.860678, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 11:24:37', 'Rotorspeed': -0.09000664, 'Windspeed': 6.504769, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 11:25:37', 'Rotorspeed': -0.09000664, 'Windspeed': 10.08674, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/04/2018 12:16:37', 'Rotorspeed': -0.09000664, 'Windspeed': 10.75622, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/04/2018 13:42:59', 'Rotorspeed': -0.09000664, 'Windspeed': 8.331232, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 13:52:27', 'Rotorspeed': -0.09000664, 'Windspeed': 11.05147, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/04/2018 13:52:56', 'Rotorspeed': -0.09000664, 'Windspeed': 11.19681, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/04/2018 15:44:52', 'Rotorspeed': -0.09000664, 'Windspeed': 10.02151, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/05/2018 09:22:48', 'Rotorspeed': -0.09000664, 'Windspeed': 4.41624, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/05/2018 10:05:30', 'Rotorspeed': -0.09000664, 'Windspeed': 7.951291, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/05/2018 10:07:05', 'Rotorspeed': -0.09000664, 'Windspeed': 6.050443, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/05/2018 10:52:42', 'Rotorspeed': -0.09000664, 'Windspeed': 7.412279, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/05/2018 12:12:33', 'Rotorspeed': -0.09000664, 'Windspeed': 2.706506, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/05/2018 13:57:11', 'Rotorspeed': -0.09000664, 'Windspeed': 10.67267, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/05/2018 14:37:22', 'Rotorspeed': -0.09000664, 'Windspeed': 6.223247, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/07/2018 03:07:15', 'Rotorspeed': -0.09000664, 'Windspeed': 8.864522, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/08/2018 22:26:20', 'Rotorspeed': -0.09000664, 'Windspeed': 9.328004, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/10/2018 06:51:02', 'Rotorspeed': -0.09000664, 'Windspeed': 13.04158, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/10/2018 09:42:15', 'Rotorspeed': -0.09000664, 'Windspeed': 4.837379, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/10/2018 09:47:28', 'Rotorspeed': -0.09000664, 'Windspeed': 12.45679, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/10/2018 10:22:54', 'Rotorspeed': -0.09000664, 'Windspeed': 9.182666, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/10/2018 11:52:52', 'Rotorspeed': -0.09000664, 'Windspeed': 12.395, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/10/2018 12:57:48', 'Rotorspeed': -0.09000664, 'Windspeed': 8.241969, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/10/2018 14:38:33', 'Rotorspeed': -0.09000664, 'Windspeed': 12.83101, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/11/2018 20:34:02', 'Rotorspeed': -0.09000664, 'Windspeed': 6.274745, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/17/2018 16:26:59', 'Rotorspeed': -0.09000664, 'Windspeed': 17.00349, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/17/2018 17:32:00', 'Rotorspeed': -0.09000664, 'Windspeed': 14.39541, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/17/2018 19:44:46', 'Rotorspeed': -0.09000664, 'Windspeed': 12.28284, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/17/2018 23:47:21', 'Rotorspeed': -0.09000664, 'Windspeed': 9.328004, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/17/2018 23:48:25', 'Rotorspeed': -0.09000664, 'Windspeed': 7.895216, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/18/2018 12:51:47', 'Rotorspeed': -0.09000664, 'Windspeed': 7.59996, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/18/2018 13:23:28', 'Rotorspeed': -0.09000664, 'Windspeed': 11.74955, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/18/2018 13:32:30', 'Rotorspeed': -0.09000664, 'Windspeed': 7.192554, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/18/2018 13:39:52', 'Rotorspeed': -0.09000664, 'Windspeed': 9.777754, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/18/2018 13:46:00', 'Rotorspeed': -0.09000664, 'Windspeed': 7.702956, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/18/2018 15:45:22', 'Rotorspeed': -0.09000664, 'Windspeed': 4.209103, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/18/2018 16:03:57', 'Rotorspeed': -0.09000664, 'Windspeed': 4.054609, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/18/2018 16:40:08', 'Rotorspeed': -0.09000664, 'Windspeed': 7.913526, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 07:09:30', 'Rotorspeed': -0.09000664, 'Windspeed': 4.256023, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/20/2018 10:56:13', 'Rotorspeed': -0.09000664, 'Windspeed': 7.745299, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 11:59:57', 'Rotorspeed': -0.09000664, 'Windspeed': 7.464921, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 13:19:48', 'Rotorspeed': -0.09000664, 'Windspeed': 8.841634, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 16:05:45', 'Rotorspeed': -0.09000664, 'Windspeed': 11.54814, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/20/2018 16:53:31', 'Rotorspeed': -0.09000664, 'Windspeed': 11.99331, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/21/2018 01:21:22', 'Rotorspeed': -0.09000664, 'Windspeed': 8.934331, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 01:37:18', 'Rotorspeed': -0.09000664, 'Windspeed': 6.836646, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:08:29', 'Rotorspeed': -0.09000664, 'Windspeed': 8.56469, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:08:54', 'Rotorspeed': -0.09000664, 'Windspeed': 5.670502, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:12:33', 'Rotorspeed': -0.09000664, 'Windspeed': 5.108602, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:18:06', 'Rotorspeed': -0.09000664, 'Windspeed': 7.815107, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:18:25', 'Rotorspeed': -0.09000664, 'Windspeed': 8.475427, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:24:04', 'Rotorspeed': -0.09000664, 'Windspeed': 7.937558, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:33:31', 'Rotorspeed': -0.09000664, 'Windspeed': 7.501542, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:33:33', 'Rotorspeed': -0.09000664, 'Windspeed': 7.375658, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 02:51:24', 'Rotorspeed': -0.09000664, 'Windspeed': 8.363276, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 03:05:06', 'Rotorspeed': -0.09000664, 'Windspeed': 8.367852, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 03:06:47', 'Rotorspeed': -0.09000664, 'Windspeed': 5.862761, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 03:14:18', 'Rotorspeed': -0.09000664, 'Windspeed': 7.680068, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 03:14:37', 'Rotorspeed': -0.09000664, 'Windspeed': 7.393968, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 03:18:24', 'Rotorspeed': -0.09000664, 'Windspeed': 7.281817, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 15:19:57', 'Rotorspeed': -0.09000664, 'Windspeed': 5.422167, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/22/2018 14:59:02', 'Rotorspeed': -0.09000664, 'Windspeed': 9.225008, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/22/2018 22:48:56', 'Rotorspeed': -0.09000664, 'Windspeed': 7.872327, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 02:39:05', 'Rotorspeed': -0.09000664, 'Windspeed': 13.58517, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 05:22:46', 'Rotorspeed': -0.09000664, 'Windspeed': 11.53441, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 05:27:24', 'Rotorspeed': -0.09000664, 'Windspeed': 9.92767, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 05:44:41', 'Rotorspeed': -0.09000664, 'Windspeed': 7.333315, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 06:16:20', 'Rotorspeed': -0.09000664, 'Windspeed': 13.40665, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 06:34:37', 'Rotorspeed': -0.09000664, 'Windspeed': 13.32768, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 06:51:42', 'Rotorspeed': -0.09000664, 'Windspeed': 13.13085, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 07:45:38', 'Rotorspeed': -0.09000664, 'Windspeed': 11.16362, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 08:03:44', 'Rotorspeed': -0.09000664, 'Windspeed': 12.07228, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 08:20:07', 'Rotorspeed': -0.09000664, 'Windspeed': 15.5421, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 10:20:24', 'Rotorspeed': -0.09000664, 'Windspeed': 13.96397, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 10:26:27', 'Rotorspeed': -0.09000664, 'Windspeed': 11.38907, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 12:59:38', 'Rotorspeed': -0.09000664, 'Windspeed': 11.19223, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 13:20:45', 'Rotorspeed': -0.09000664, 'Windspeed': 10.25955, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 23:27:44', 'Rotorspeed': -0.09000664, 'Windspeed': 6.845801, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 00:33:19', 'Rotorspeed': -0.09000664, 'Windspeed': 7.08498, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 00:34:34', 'Rotorspeed': -0.09000664, 'Windspeed': 10.78483, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 00:53:19', 'Rotorspeed': -0.09000664, 'Windspeed': 10.07759, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 06:34:53', 'Rotorspeed': -0.09000664, 'Windspeed': 6.757682, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 07:01:29', 'Rotorspeed': -0.09000664, 'Windspeed': 7.418001, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 07:28:42', 'Rotorspeed': -0.09000664, 'Windspeed': 8.195048, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 07:29:32', 'Rotorspeed': -0.09000664, 'Windspeed': 9.547729, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 07:44:17', 'Rotorspeed': -0.09000664, 'Windspeed': 9.867017, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 08:09:33', 'Rotorspeed': -0.09000664, 'Windspeed': 11.05147, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 09:45:57', 'Rotorspeed': -0.09000664, 'Windspeed': 6.729072, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 10:17:23', 'Rotorspeed': -0.09000664, 'Windspeed': 12.82186, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 10:19:39', 'Rotorspeed': -0.09000664, 'Windspeed': 5.923414, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 10:22:29', 'Rotorspeed': -0.09000664, 'Windspeed': 9.285662, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 10:30:20', 'Rotorspeed': -0.09000664, 'Windspeed': 9.932247, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 10:40:47', 'Rotorspeed': -0.09000664, 'Windspeed': 7.942136, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 10:45:41', 'Rotorspeed': -0.09000664, 'Windspeed': 10.20347, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 11:44:38', 'Rotorspeed': -0.09000664, 'Windspeed': 11.2197, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 11:56:27', 'Rotorspeed': -0.09000664, 'Windspeed': 14.73758, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 13:43:41', 'Rotorspeed': -0.09000664, 'Windspeed': 7.239474, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 15:13:11', 'Rotorspeed': -0.09000664, 'Windspeed': 5.23563, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 15:32:25', 'Rotorspeed': -0.09000664, 'Windspeed': 6.05502, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 16:34:21', 'Rotorspeed': -0.09000664, 'Windspeed': 11.47719, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 16:53:38', 'Rotorspeed': -0.09000664, 'Windspeed': 7.969602, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/24/2018 16:58:35', 'Rotorspeed': -0.09000664, 'Windspeed': 7.590805, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 10:18:18', 'Rotorspeed': -0.09000664, 'Windspeed': 13.69732, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/25/2018 10:58:27', 'Rotorspeed': -0.09000664, 'Windspeed': 9.773176, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 12:01:59', 'Rotorspeed': -0.09000664, 'Windspeed': 11.59506, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/25/2018 12:06:02', 'Rotorspeed': -0.09000664, 'Windspeed': 8.537224, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 15:46:33', 'Rotorspeed': -0.09000664, 'Windspeed': 10.12908, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/25/2018 17:08:04', 'Rotorspeed': -0.09000664, 'Windspeed': 12.292, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/25/2018 18:43:58', 'Rotorspeed': -0.09000664, 'Windspeed': 9.108279, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 21:19:04', 'Rotorspeed': -0.09000664, 'Windspeed': 9.253618, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/26/2018 10:08:35', 'Rotorspeed': -0.09000664, 'Windspeed': 11.85255, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 10:58:10', 'Rotorspeed': -0.09000664, 'Windspeed': 7.398546, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/26/2018 13:48:44', 'Rotorspeed': -0.09000664, 'Windspeed': 9.838407, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/26/2018 14:52:05', 'Rotorspeed': -0.09000664, 'Windspeed': 13.88958, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 14:52:17', 'Rotorspeed': -0.09000664, 'Windspeed': 7.993634, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/26/2018 15:08:25', 'Rotorspeed': -0.09000664, 'Windspeed': 18.57247, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 15:12:06', 'Rotorspeed': -0.09000664, 'Windspeed': 8.976673, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/26/2018 15:52:49', 'Rotorspeed': -0.09000664, 'Windspeed': 9.936825, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/26/2018 16:10:36', 'Rotorspeed': -0.09000664, 'Windspeed': 15.05573, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 16:40:34', 'Rotorspeed': -0.09000664, 'Windspeed': 6.612343, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/26/2018 17:01:15', 'Rotorspeed': -0.09000664, 'Windspeed': 12.4751, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 17:10:26', 'Rotorspeed': -0.09000664, 'Windspeed': 10.99997, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 17:46:21', 'Rotorspeed': -0.09000664, 'Windspeed': 14.82112, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 22:56:29', 'Rotorspeed': -0.09000664, 'Windspeed': 5.656769, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/27/2018 08:34:37', 'Rotorspeed': -0.09000664, 'Windspeed': 5.169255, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/29/2018 17:33:32', 'Rotorspeed': -0.09000664, 'Windspeed': 5.93257, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/29/2018 17:46:20', 'Rotorspeed': -0.09000664, 'Windspeed': 6.892721, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 08:47:22', 'Rotorspeed': -0.09000664, 'Windspeed': 5.426745, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 09:42:29', 'Rotorspeed': -0.09000664, 'Windspeed': 5.553773, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 13:09:56', 'Rotorspeed': -0.09000664, 'Windspeed': 3.282139, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/30/2018 13:23:09', 'Rotorspeed': -0.09000664, 'Windspeed': 6.959096, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 13:23:22', 'Rotorspeed': -0.09000664, 'Windspeed': 5.070837, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 13:53:28', 'Rotorspeed': -0.09000664, 'Windspeed': 8.841634, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/01/2018 04:19:41', 'Rotorspeed': -0.07500553, 'Windspeed': 4.916342, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/01/2018 08:19:47', 'Rotorspeed': -0.07500553, 'Windspeed': 3.848617, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/01/2018 09:30:35', 'Rotorspeed': -0.07500553, 'Windspeed': 3.071569, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/02/2018 07:33:20', 'Rotorspeed': -0.07500553, 'Windspeed': 8.747793, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/02/2018 08:42:09', 'Rotorspeed': -0.07500553, 'Windspeed': 8.363276, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/02/2018 13:00:05', 'Rotorspeed': -0.07500553, 'Windspeed': 8.475427, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/02/2018 13:02:47', 'Rotorspeed': -0.07500553, 'Windspeed': 15.56613, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/02/2018 13:59:15', 'Rotorspeed': -0.07500553, 'Windspeed': 9.341737, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/02/2018 19:57:57', 'Rotorspeed': -0.07500553, 'Windspeed': 18.74985, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/02/2018 23:17:11', 'Rotorspeed': -0.07500553, 'Windspeed': 11.93609, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/03/2018 00:19:02', 'Rotorspeed': -0.07500553, 'Windspeed': 9.032749, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/03/2018 07:57:47', 'Rotorspeed': -0.07500553, 'Windspeed': 8.972095, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/03/2018 10:37:57', 'Rotorspeed': -0.07500553, 'Windspeed': 5.553773, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 04:18:10', 'Rotorspeed': -0.07500553, 'Windspeed': 7.398546, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 04:54:09', 'Rotorspeed': -0.07500553, 'Windspeed': 6.397196, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 06:18:48', 'Rotorspeed': -0.07500553, 'Windspeed': 4.66343, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/04/2018 07:58:56', 'Rotorspeed': -0.07500553, 'Windspeed': 6.789725, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 08:15:57', 'Rotorspeed': -0.07500553, 'Windspeed': 8.452538, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 10:15:29', 'Rotorspeed': -0.07500553, 'Windspeed': 12.36753, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/04/2018 12:57:17', 'Rotorspeed': -0.07500553, 'Windspeed': 8.199626, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 16:16:11', 'Rotorspeed': -0.07500553, 'Windspeed': 10.29731, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/04/2018 18:32:24', 'Rotorspeed': -0.07500553, 'Windspeed': 6.406351, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 18:34:53', 'Rotorspeed': -0.07500553, 'Windspeed': 6.326243, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/05/2018 08:03:33', 'Rotorspeed': -0.07500553, 'Windspeed': 5.516008, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/05/2018 10:07:24', 'Rotorspeed': -0.07500553, 'Windspeed': 4.139295, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/05/2018 12:48:33', 'Rotorspeed': -0.07500553, 'Windspeed': 8.302622, 'WindSpeed_Group': 'B'}
# ...
# {'Timestamp': '04/22/2018 01:03:05', 'Rotorspeed': 0.2700199, 'Windspeed': 2.017577, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/25/2018 12:41:10', 'Rotorspeed': 0.2700199, 'Windspeed': 5.829574, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 13:07:31', 'Rotorspeed': 0.2700199, 'Windspeed': 15.10722, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 13:59:53', 'Rotorspeed': 0.2700199, 'Windspeed': 11.99789, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/27/2018 19:38:27', 'Rotorspeed': 0.2700199, 'Windspeed': 5.220753, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/28/2018 20:09:57', 'Rotorspeed': 0.2700199, 'Windspeed': 3.816574, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/03/2018 04:25:30', 'Rotorspeed': 0.285021, 'Windspeed': 7.094135, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/06/2018 13:13:45', 'Rotorspeed': 0.285021, 'Windspeed': 11.45888, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/06/2018 18:46:40', 'Rotorspeed': 0.285021, 'Windspeed': 9.585494, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/06/2018 20:06:51', 'Rotorspeed': 0.285021, 'Windspeed': 7.319582, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/06/2018 21:02:38', 'Rotorspeed': 0.285021, 'Windspeed': 3.745621, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/15/2018 15:31:38', 'Rotorspeed': 0.285021, 'Windspeed': 12.28742, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/15/2018 15:41:14', 'Rotorspeed': 0.285021, 'Windspeed': 13.47302, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/15/2018 15:57:10', 'Rotorspeed': 0.285021, 'Windspeed': 8.620765, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/15/2018 16:00:12', 'Rotorspeed': 0.285021, 'Windspeed': 10.68183, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/15/2018 16:03:01', 'Rotorspeed': 0.285021, 'Windspeed': 12.64791, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/16/2018 01:32:43', 'Rotorspeed': 0.285021, 'Windspeed': 2.827812, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/16/2018 01:39:29', 'Rotorspeed': 0.285021, 'Windspeed': 1.914581, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/20/2018 01:02:25', 'Rotorspeed': 0.285021, 'Windspeed': 5.529741, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 21:16:45', 'Rotorspeed': 0.285021, 'Windspeed': 2.31741, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/21/2018 21:20:11', 'Rotorspeed': 0.285021, 'Windspeed': 3.113912, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/21/2018 23:02:04', 'Rotorspeed': 0.285021, 'Windspeed': 2.823235, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/21/2018 23:02:11', 'Rotorspeed': 0.285021, 'Windspeed': 3.91957, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/21/2018 23:41:51', 'Rotorspeed': 0.285021, 'Windspeed': 1.081458, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/22/2018 00:29:22', 'Rotorspeed': 0.285021, 'Windspeed': 1.788697, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/23/2018 00:32:56', 'Rotorspeed': 0.285021, 'Windspeed': 13.65498, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/25/2018 13:25:19', 'Rotorspeed': 0.285021, 'Windspeed': 11.02858, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/28/2018 13:48:30', 'Rotorspeed': 0.285021, 'Windspeed': 6.321665, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/30/2018 17:32:09', 'Rotorspeed': 0.285021, 'Windspeed': 4.420817, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/30/2018 17:32:13', 'Rotorspeed': 0.285021, 'Windspeed': 4.66343, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/02/2018 04:31:06', 'Rotorspeed': 0.3000221, 'Windspeed': 7.609116, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/06/2018 14:03:04', 'Rotorspeed': 0.3000221, 'Windspeed': 10.30647, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/06/2018 20:19:14', 'Rotorspeed': 0.3000221, 'Windspeed': 6.500192, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/11/2018 18:46:26', 'Rotorspeed': 0.3000221, 'Windspeed': 6.668419, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/15/2018 10:01:14', 'Rotorspeed': 0.3000221, 'Windspeed': 10.32134, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/15/2018 15:31:41', 'Rotorspeed': 0.3000221, 'Windspeed': 12.49341, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/16/2018 02:54:11', 'Rotorspeed': 0.3000221, 'Windspeed': 2.097685, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/16/2018 06:00:36', 'Rotorspeed': 0.3000221, 'Windspeed': 1.737199, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/20/2018 05:07:32', 'Rotorspeed': 0.3000221, 'Windspeed': 5.562928, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 21:30:33', 'Rotorspeed': 0.3000221, 'Windspeed': 2.341442, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/22/2018 00:36:26', 'Rotorspeed': 0.3000221, 'Windspeed': 2.36433, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/23/2018 09:51:03', 'Rotorspeed': 0.3000221, 'Windspeed': 9.965435, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 12:57:39', 'Rotorspeed': 0.3000221, 'Windspeed': 15.86138, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 12:56:09', 'Rotorspeed': 0.3000221, 'Windspeed': 14.63916, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 13:44:20', 'Rotorspeed': 0.3000221, 'Windspeed': 11.23457, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/06/2018 14:01:36', 'Rotorspeed': 0.3150232, 'Windspeed': 9.571761, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/06/2018 22:03:25', 'Rotorspeed': 0.3150232, 'Windspeed': 2.402096, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/12/2018 10:39:04', 'Rotorspeed': 0.3150232, 'Windspeed': 9.524841, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/15/2018 09:59:56', 'Rotorspeed': 0.3150232, 'Windspeed': 8.414773, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/15/2018 15:42:39', 'Rotorspeed': 0.3150232, 'Windspeed': 9.099124, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/15/2018 15:46:53', 'Rotorspeed': 0.3150232, 'Windspeed': 13.38834, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/15/2018 18:05:37', 'Rotorspeed': 0.3150232, 'Windspeed': 10.52734, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/16/2018 21:01:59', 'Rotorspeed': 0.3150232, 'Windspeed': 7.29555, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 20:55:10', 'Rotorspeed': 0.3150232, 'Windspeed': 4.139295, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/21/2018 21:30:31', 'Rotorspeed': 0.3150232, 'Windspeed': 2.214414, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/21/2018 21:41:54', 'Rotorspeed': 0.3150232, 'Windspeed': 2.373486, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/21/2018 21:59:36', 'Rotorspeed': 0.3150232, 'Windspeed': 2.655008, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/23/2018 05:24:35', 'Rotorspeed': 0.3150232, 'Windspeed': 11.89947, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/23/2018 18:26:43', 'Rotorspeed': 0.3150232, 'Windspeed': 8.5933, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 13:19:56', 'Rotorspeed': 0.3150232, 'Windspeed': 16.57778, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/28/2018 12:57:25', 'Rotorspeed': 0.3150232, 'Windspeed': 8.208781, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/29/2018 23:45:36', 'Rotorspeed': 0.3150232, 'Windspeed': 4.214825, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/18/2018 20:29:59', 'Rotorspeed': 0.3300243, 'Windspeed': 4.228558, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/21/2018 20:49:27', 'Rotorspeed': 0.3300243, 'Windspeed': 3.980223, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/21/2018 21:46:07', 'Rotorspeed': 0.3300243, 'Windspeed': 3.371402, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/21/2018 22:05:40', 'Rotorspeed': 0.3300243, 'Windspeed': 2.462749, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/24/2018 11:38:11', 'Rotorspeed': 0.3300243, 'Windspeed': 11.18765, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/04/2018 23:42:00', 'Rotorspeed': 0.3450254, 'Windspeed': 7.572495, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 18:38:26', 'Rotorspeed': 0.3450254, 'Windspeed': 6.092785, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 21:04:56', 'Rotorspeed': 0.3450254, 'Windspeed': 3.483554, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/21/2018 21:18:28', 'Rotorspeed': 0.3450254, 'Windspeed': 3.671235, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/21/2018 21:25:29', 'Rotorspeed': 0.3450254, 'Windspeed': 3.63347, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/22/2018 01:30:08', 'Rotorspeed': 0.3450254, 'Windspeed': 1.54494, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/22/2018 01:34:05', 'Rotorspeed': 0.3450254, 'Windspeed': 1.87796, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/25/2018 06:02:28', 'Rotorspeed': 0.3450254, 'Windspeed': 7.024327, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/09/2018 01:42:05', 'Rotorspeed': 0.3600265, 'Windspeed': 3.595705, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/16/2018 03:44:34', 'Rotorspeed': 0.3600265, 'Windspeed': 2.55659, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/18/2018 22:38:40', 'Rotorspeed': 0.3600265, 'Windspeed': 7.660614, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 21:19:01', 'Rotorspeed': 0.3600265, 'Windspeed': 2.992606, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/02/2018 02:56:17', 'Rotorspeed': 0.3750276, 'Windspeed': 5.619004, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/03/2018 12:48:29', 'Rotorspeed': 0.3750276, 'Windspeed': 6.288478, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/03/2018 23:33:42', 'Rotorspeed': 0.3750276, 'Windspeed': 4.116407, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/06/2018 13:55:04', 'Rotorspeed': 0.3750276, 'Windspeed': 7.876905, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/17/2018 04:26:49', 'Rotorspeed': 0.3750276, 'Windspeed': 10.32592, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/21/2018 21:25:04', 'Rotorspeed': 0.3750276, 'Windspeed': 2.630975, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/22/2018 00:40:14', 'Rotorspeed': 0.3750276, 'Windspeed': 3.741044, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/22/2018 00:40:15', 'Rotorspeed': 0.3750276, 'Windspeed': 3.741044, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/22/2018 01:07:45', 'Rotorspeed': 0.3750276, 'Windspeed': 2.013, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/25/2018 13:25:27', 'Rotorspeed': 0.3900287, 'Windspeed': 10.41518, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/06/2018 13:51:00', 'Rotorspeed': 0.4050298, 'Windspeed': 8.766104, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/19/2018 00:14:45', 'Rotorspeed': 0.4050298, 'Windspeed': 7.516419, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 21:12:41', 'Rotorspeed': 0.4200309, 'Windspeed': 2.617243, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/25/2018 05:20:33', 'Rotorspeed': 0.4200309, 'Windspeed': 7.351625, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 13:13:48', 'Rotorspeed': 0.4200309, 'Windspeed': 18.91922, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/03/2018 00:28:28', 'Rotorspeed': 0.4350321, 'Windspeed': 8.279734, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/21/2018 20:10:25', 'Rotorspeed': 0.4350321, 'Windspeed': 4.349864, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/21/2018 21:13:09', 'Rotorspeed': 0.4350321, 'Windspeed': 2.954841, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/21/2018 23:57:46', 'Rotorspeed': 0.4350321, 'Windspeed': 3.792542, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/25/2018 13:07:15', 'Rotorspeed': 0.4350321, 'Windspeed': 15.87054, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/25/2018 13:09:36', 'Rotorspeed': 0.4350321, 'Windspeed': 12.10089, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/21/2018 20:06:58', 'Rotorspeed': 0.4500332, 'Windspeed': 4.598199, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/25/2018 13:13:45', 'Rotorspeed': 0.4500332, 'Windspeed': 15.18619, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 23:15:13', 'Rotorspeed': 0.4650343, 'Windspeed': 6.841223, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 13:08:01', 'Rotorspeed': 0.4650343, 'Windspeed': 16.22187, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/25/2018 13:10:35', 'Rotorspeed': 0.4650343, 'Windspeed': 14.71813, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/19/2018 18:16:15', 'Rotorspeed': 0.4800354, 'Windspeed': 6.317088, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/25/2018 13:13:17', 'Rotorspeed': 0.4800354, 'Windspeed': 18.35274, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/21/2018 20:13:23', 'Rotorspeed': 0.5100376, 'Windspeed': 5.276828, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/29/2018 20:23:49', 'Rotorspeed': 0.5250387, 'Windspeed': 3.483554, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/01/2018 18:04:41', 'Rotorspeed': 0.5400398, 'Windspeed': 3.001761, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/22/2018 12:03:30', 'Rotorspeed': 0.5550409, 'Windspeed': 10.97708, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/18/2018 07:00:33', 'Rotorspeed': 0.570042, 'Windspeed': 4.701195, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/18/2018 07:03:52', 'Rotorspeed': 0.570042, 'Windspeed': 5.562928, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/23/2018 06:53:44', 'Rotorspeed': 0.570042, 'Windspeed': 13.64125, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/07/2018 07:41:27', 'Rotorspeed': 0.5850431, 'Windspeed': 4.828224, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/03/2018 06:21:58', 'Rotorspeed': 0.6000442, 'Windspeed': 6.771415, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/17/2018 23:59:45', 'Rotorspeed': 0.6000442, 'Windspeed': 5.104024, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/11/2018 01:39:25', 'Rotorspeed': 0.6150454, 'Windspeed': 4.710351, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/06/2018 23:07:11', 'Rotorspeed': 0.6450475, 'Windspeed': 2.818657, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/19/2018 15:32:50', 'Rotorspeed': 0.6450475, 'Windspeed': 5.632737, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/10/2018 07:14:12', 'Rotorspeed': 0.6900508, 'Windspeed': 10.11077, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/10/2018 14:17:41', 'Rotorspeed': 0.7200531, 'Windspeed': 12.75663, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/24/2018 17:57:14', 'Rotorspeed': 0.7200531, 'Windspeed': 5.137211, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 17:56:49', 'Rotorspeed': 0.7950586, 'Windspeed': 6.912176, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/04/2018 01:50:30', 'Rotorspeed': 0.8100597, 'Windspeed': 6.041287, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/26/2018 14:56:20', 'Rotorspeed': 0.8100597, 'Windspeed': 15.68744, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/12/2018 10:14:44', 'Rotorspeed': 0.8400619, 'Windspeed': 9.852139, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/09/2018 18:01:53', 'Rotorspeed': 0.855063, 'Windspeed': 7.942136, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/11/2018 18:33:09', 'Rotorspeed': 0.9000663, 'Windspeed': 6.8561, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/20/2018 12:07:37', 'Rotorspeed': 0.9300686, 'Windspeed': 7.759032, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/15/2018 23:28:09', 'Rotorspeed': 1.035076, 'Windspeed': 8.578423, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/12/2018 08:01:22', 'Rotorspeed': 1.08008, 'Windspeed': 10.76079, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/20/2018 22:49:01', 'Rotorspeed': 1.08008, 'Windspeed': 5.104024, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/29/2018 09:58:54', 'Rotorspeed': 1.125083, 'Windspeed': 5.506853, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/02/2018 13:34:59', 'Rotorspeed': 1.200088, 'Windspeed': 13.87585, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/26/2018 20:19:00', 'Rotorspeed': 1.260093, 'Windspeed': 11.6889, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/09/2018 18:01:58', 'Rotorspeed': 1.365101, 'Windspeed': 5.679657, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/12/2018 09:00:19', 'Rotorspeed': 1.515112, 'Windspeed': 5.169255, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/08/2018 17:28:45', 'Rotorspeed': 1.590117, 'Windspeed': 5.483965, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/22/2018 07:47:47', 'Rotorspeed': 2.025149, 'Windspeed': 4.396785, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/15/2018 12:25:22', 'Rotorspeed': 2.790205, 'Windspeed': 12.395, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/09/2018 18:13:08', 'Rotorspeed': 5.145379, 'Windspeed': 6.592888, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/22/2018 05:08:02', 'Rotorspeed': 5.580411, 'Windspeed': 2.312832, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/04/2018 16:58:49', 'Rotorspeed': 6.450475, 'Windspeed': 7.62857, 'WindSpeed_Group': 'B'}
# {'Timestamp': '04/29/2018 07:17:00', 'Rotorspeed': 7.695567, 'Windspeed': 3.006339, 'WindSpeed_Group': 'A'}
# {'Timestamp': '04/17/2018 21:16:09', 'Rotorspeed': 10.71079, 'Windspeed': 10.48957, 'WindSpeed_Group': 'C'}
# {'Timestamp': '04/05/2018 20:19:02', 'Rotorspeed': 13.38099, 'Windspeed': 2.321988, 'WindSpeed_Group': 'A'}

# %%
import numpy as np
import time

def original_integration(f, a, b, n):
    h = (b - a) / n
    result = 0.5 * (f(a) + f(b))
    for i in range(1, n):
        result += f(a + i * h)
    result *= h
    return result

def vectorized_integration(f, a, b, n):
    x = np.linspace(a, b, n + 1)
    h = (b - a) / n
    result = 0.5 * (f(a) + f(b)) + np.sum(f(x[1:-1]))
    result *= h
    return result

# Function to integrate: f(x) = 8x^12 + 11x^10 - 12x^8 + 3
def f(x):
    return 8 * x**12 + 11 * x**10 - 12 * x**8 + 3

# Interval [a, b] and number of subintervals
a, b = -15, 17
n = 1000000  # Adjust the number of subintervals

# Timing the original integration
start_time = time.time()
result_original = original_integration(f, a, b, n)
end_time = time.time()
time_original = end_time - start_time

# Timing the vectorized integration
start_time = time.time()
result_vectorized = vectorized_integration(f, a, b, n)
end_time = time.time()
time_vectorized = end_time - start_time

# Display results and timings
print("Original Result:", result_original)
print("Vectorized Result:", result_vectorized)
print("Time taken (Original): {:.6f} seconds".format(time_original))
print("Time taken (Vectorized): {:.6f} seconds".format(time_vectorized))
# Out:
# Original Result: 7335495724470886.0
# Vectorized Result: 7335495724471518.0
# Time taken (Original): 0.583538 seconds
# Time taken (Vectorized): 0.156907 seconds

# %%
import numpy as np

# a) Use numpy.genfromtxt to read the file into a 2-dimensional numpy array
file_path = './data/prob4_AB0208.csv'
data = np.genfromtxt(file_path, delimiter=',', dtype=str, skip_header=1)

# Display the original data
print("Original Data:")
print(data)

# b) Use Boolean masking to drop the rows that contain nan entries
data = data[~np.any(np.isnan(data.astype(float)), axis=1)]

# Display the data after dropping rows with nan entries
print("\nData after dropping rows with nan entries:")
print(data)

# c) Convert the time entries into a human-readable format (e.g., YYYY-MM-DD HH:mm:ss)
time_column_index = 0

def convert_to_datetime(x):
    try:
        return np.datetime64(x, 's').astype('datetime64[s]')
    except ValueError:
        return np.datetime64('NaT')

data[:, time_column_index] = np.vectorize(convert_to_datetime)(data[:, time_column_index])

# Display the data after converting time entries
print("\nData after converting time entries:")
print(data)

# d) Add a new row that contains the averages of the numeric columns, skipping 'NaT' for the time column
numeric_data = np.ma.masked_equal(data[:, 1:].astype(float), np.nan)
averages = np.mean(numeric_data, axis=0)
averages = np.insert(averages.filled(np.nan), time_column_index, np.nan)  # Fill 'NaT' with nan for the time column

# Display the averages
print("\nAverages of numeric columns:")
print(averages)

# Create a new row with the averages
data_with_averages = np.vstack([data, averages])

# Display the data with the new row of averages
print("\nData with the new row of averages:")
print(data_with_averages)
# Out:
# Original Data:
# [['268.424561' '0.868437' '0.000000' '1672790400.000000' '0.300850'
#   '-2.382514']
#  ['267.929047' '0.869720' '0.039103' '1672794000.000000' '0.152142'
#   '-2.623582']
#  ['267.227448' '0.872451' '0.069010' 'nan' '-0.037141' '-2.734714']
#  ...
#  ['270.075745' '0.896504' '0.000000' '1672693200.000000' '-0.731940'
#   '-0.121091']
#  ['270.487732' '0.877308' '0.000651' '1672696800.000000' '-1.110839'
#   '-0.406309']
#  ['270.797119' '0.862045' '0.013021' '1672700400.000000' '-1.196100'
#   '-0.412851']]
#
# Data after dropping rows with nan entries:
# [['268.424561' '0.868437' '0.000000' '1672790400.000000' '0.300850'
#   '-2.382514']
#  ['267.929047' '0.869720' '0.039103' '1672794000.000000' '0.152142'
#   '-2.623582']
#  ['266.758057' '0.873738' '0.095133' '1672801200.000000' '0.443858'
#   '-2.607769']
#  ...
#  ['270.075745' '0.896504' '0.000000' '1672693200.000000' '-0.731940'
#   '-0.121091']
#  ['270.487732' '0.877308' '0.000651' '1672696800.000000' '-1.110839'
#   '-0.406309']
#  ['270.797119' '0.862045' '0.013021' '1672700400.000000' '-1.196100'
#   '-0.412851']]
#
# Data after converting time entries:
# [['NaT' '0.868437' '0.000000' '1672790400.000000' '0.300850' '-2.382514']
#  ['NaT' '0.869720' '0.039103' '1672794000.000000' '0.152142' '-2.623582']
#  ['NaT' '0.873738' '0.095133' '1672801200.000000' '0.443858' '-2.607769']
#  ...
#  ['NaT' '0.896504' '0.000000' '1672693200.000000' '-0.731940' '-0.121091']
#  ['NaT' '0.877308' '0.000651' '1672696800.000000' '-1.110839' '-0.406309']
#  ['NaT' '0.862045' '0.013021' '1672700400.000000' '-1.196100' '-0.412851']]
#
# Averages of numeric columns:
# [            nan  8.35351444e-01  1.65330722e-01  1.67288054e+09
#   2.64383717e-01 -2.23836939e-01]
#
# Data with the new row of averages:
# [['NaT' '0.868437' '0.000000' '1672790400.000000' '0.300850' '-2.382514']
#  ['NaT' '0.869720' '0.039103' '1672794000.000000' '0.152142' '-2.623582']
#  ['NaT' '0.873738' '0.095133' '1672801200.000000' '0.443858' '-2.607769']
#  ...
#  ['NaT' '0.877308' '0.000651' '1672696800.000000' '-1.110839' '-0.406309']
#  ['NaT' '0.862045' '0.013021' '1672700400.000000' '-1.196100' '-0.412851']
#  ['nan' '0.8353514444444445' '0.16533072222222225' '1672880540.0'
#   '0.26438371666666655' '-0.22383693888888898']]

# %%
##### imports #####

import requests
import json
import sys

# this has to do with pass by value / reference
from copy import deepcopy

##### config #####

english = True
# english = False


##### helpers #####


# notebook replacement of sys.exit()
# call with raise StopExecution
class StopExecution(Exception):
    def _render_traceback_(self):
        pass

query_template = {
    "query": [], # list of query items
    "response": {
        "format": "json"
    }
}

query_item_template = {
    "code": "", # variable
    "selection": {
        "filter": "item",
        "values": [] # list of strings
    }
}


##### main #####


with requests.Session() as session:

    '''
    first, some browsing in order to get the correct database
    you can do this with a browser too (but translation may become an issue)
    '''

    lang_id = 'en' if english else 'fi'
    base_url = f'https://pxdata.stat.fi/PXWeb/api/v1/{lang_id}/StatFin'
#     response = session.get(base_url)

#     for item in response.json():
#         print(item['id'], item['text'])

#     # stop execution
#     raise StopExecution

    '''
    next, append the id of your thing of interest to the url
    (EDIT the adopt below)
    '''

    catalogue_url = f'{base_url}/khi'
    # response = session.get(catalogue_url)

    '''
    check what .px files are available in the "catalogue"
    '''
#     for item in response.json():
#         print(item['id'], item['text'])

#     # stop execution
#     raise StopExecution

    '''
    once you decide what .px file interests you, 
    EDIT it below in order to fetch the available data headers

    '''

    headers_url = f'{base_url}/khi/statfin_khi_pxt_11xc.px'
    response = session.get(headers_url)

    myjson = response.json()
    # print()
    # print('variables:', len(myjson['variables']))
    # print()
    # for var in myjson['variables']:
    #     print(var['text'])
    # print()

#     if english:
#         tmp_url = headers_url.replace('/en/','/fi/')
#         response = session.get(tmp_url)
#         myjson = response.json()
#         print()
#         print('the corresponding variables in finnish (needed in the actual query):')
#         print()
#         for var in myjson['variables']:
#             print(var['text'])
#         print()

#     # stop execution
#     raise StopExecution

    '''
    okay, but then things get more serious as we build the actual query for the data

    first, fetch the maximum values that one can download
    (this is kind of hi-tech, got it from the documentation)
    (which typically sucks in free & public apis like this)
    '''
    response = session.get(f'https://statfin.stat.fi/PXWeb/api/v1/{lang_id}/?config')
    maxvalues = response.json()['maxValues']

    '''
    query building (we don't request anything yet)
    please edit only the "for myvar" line
    '''
    query = deepcopy(query_template)
    total_values = 1
    for myvar in ['Hyödyke', 'Vuosi', 'Tiedot']: # EDIT this line
        myvalues = []
        query_item = deepcopy(query_item_template)
        for v in myjson['variables']:
            if v['code'] == myvar:
                myvalues = v['values']
        total_values = total_values * len(myvalues)
        query_item['code'] = myvar
        query_item['selection']['values'] = myvalues
        query['query'].append(query_item)
    if total_values > maxvalues:
        print('your query is too big, try again with fewer variables')
        raise StopExecution


    '''
    obtain the actual data with a "post" request
    that's like submitting a web form
    and cannot be done by gui browsing anymore
    '''
    response = session.post(headers_url, json=query)

    '''
    finally, dump the data to a file
    '''
    myjson = response.json()
    with open('test.json', 'w') as handle:
        json.dump(myjson, handle, indent=4)
